# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %%
df = pd.read_excel("swiggy_data.xlsx")
df.head()
# Out:
#        State       City Order Date           Restaurant Name  \
# 0  Karnataka  Bengaluru 2025-06-29  Anand Sweets & Savouries
# 1  Karnataka  Bengaluru 2025-04-03     Srinidhi Sagar Deluxe
# 2  Karnataka  Bengaluru 2025-01-15     Srinidhi Sagar Deluxe
# 3  Karnataka  Bengaluru 2025-04-17     Srinidhi Sagar Deluxe
# 4  Karnataka  Bengaluru 2025-03-13     Srinidhi Sagar Deluxe
#
#                Location     Category             Dish Name  Price (INR)  \
# 0  Rajarajeshwari Nagar        Snack  Butter Murukku-200gm        133.9
# 1               Kengeri  Recommended            Badam Milk         52.0
# 2               Kengeri  Recommended        Chow Chow Bath        117.0
# 3               Kengeri  Recommended           Kesari Bath         65.0
# 4               Kengeri  Recommended            Mix Raitha        130.0
#
#    Rating  Rating Count
# 0     4.0             0
# 1     4.5            25
# 2     4.7            48
# 3     4.6            65
# 4     4.0             0

# %%
df.shape
# Out:
# (197430, 10)

# %%
df.isnull().count()
# Out:
# State              197430
# City               197430
# Order Date         197430
# Restaurant Name    197430
# Location           197430
# Category           197430
# Dish Name          197430
# Price (INR)        197430
# Rating             197430
# Rating Count       197430
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 197430 entries, 0 to 197429
# Data columns (total 10 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   State            197430 non-null  object
#  1   City             197430 non-null  object
#  2   Order Date       197430 non-null  datetime64[ns]
#  3   Restaurant Name  197430 non-null  object
#  4   Location         197430 non-null  object
#  5   Category         197430 non-null  object
#  6   Dish Name        197430 non-null  object
#  7   Price (INR)      197430 non-null  float64
#  8   Rating           197430 non-null  float64
#  9   Rating Count     197430 non-null  int64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(6)
# memory usage: 15.1+ MB

# %% [markdown]
# ## KPI's

# %% [markdown]
# ### Total Sales

# %%
total_sales = df["Price (INR)"].sum()
print("Total Sales (INR): ",round(total_sales,2)
# Out:
# Total Sales (INR):  53012505.77

# %% [markdown]
# ### Average Rating

# %%
average_rating = df["Rating"].mean()
print("Average Rating: ",round(average_rating,2))
# Out:
# Average Rating:  4.34

# %% [markdown]
# ### Average Order

# %%
average_order = df["Price (INR)"].mean()
print("Average Order: ",round(average_order,2))
# Out:
# Average Order:  268.51

# %% [markdown]
# ### Rating Count

# %%
rating_count = df["Rating Count"].sum()
print("Total Rating: ",round(rating_count,2))
# Out:
# Total Rating:  5591574

# %% [markdown]
# ### Total Order

# %%
total_order = len(df)
print("Total Order: ",round(total_order,2))
# Out:
# Total Order:  197430

# %% [markdown]
# ## Charts Design

# %% [markdown]
# ### Monthly Sales Trend

# %%
df["Order Date"] = pd.to_datetime(df["Order Date"])
df["Year Month"] = df["Order Date"].dt.to_period("M").astype(str)
monthly_revenue = df.groupby("Year Month")["Price (INR)"].sum().reset_index()
plt.plot(monthly_revenue["Year Month"], monthly_revenue["Price (INR)"])
plt.xticks(rotation = 45)
plt.xlabel("Month")
plt.ylabel("Revenue (INR)")
plt.title("Monthly Revenue Trend")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Daily Sales trend

# %%
df["DayName"] = pd.to_datetime(df["Order Date"]).dt.day_name()
daily_revenue = (df.groupby("DayName")["Price (INR)"]
                 .sum()
                 .reindex(["Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday"])
                )
plt.figure(figsize=(10,5))
plt.bar(daily_revenue.index, daily_revenue.values)
plt.xticks(rotation = 45)
plt.xlabel("Day Name")
plt.ylabel("Revenue (INR)")
plt.title("Daily Revenue Trend")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Total Sales by Food Type

# %%
df["Dish Name"].unique()
# Out:
# array(['Butter Murukku-200gm', 'Badam Milk', 'Chow Chow Bath', ...,
#        'Chilli cheese momo ', 'Veg Momos (8 Pc)', 'Soya Momo'],
#       dtype=object)

# %%
non_veg_keywords = [
    "chicken", "egg", "fish", "mutton",
    "prawn", "briyani", "kabab", "kebab",
    "non-veg", "non veg"
]

df["food_category"] = np.where(
    df["Dish Name"].str.lower().str.contains("|".join(non_veg_keywords), na=False),
    "Non-Veg",
    "Veg"
)

# %%
food_revenue = (
    df.groupby("food_category")["Price (INR)"]
    .sum()
    .reset_index()
)

plt.figure(figsize=(10,5))
plt.bar(food_revenue["food_category"], food_revenue["Price (INR)"])
plt.xticks(rotation = 45)
plt.xlabel("food category")
plt.ylabel("Revenue (INR)")
plt.title("Revenue by food type")
plt.tight_layout()
plt.show()

# %%
# Plot
plt.figure(figsize=(8, 8))

colors = plt.cm.Pastel1.colors  # nice soft colors

plt.pie(
    food_revenue["Price (INR)"],
    labels=food_revenue["food_category"],
    autopct='%1.1f%%',
    startangle=140,
    colors=colors,
    wedgeprops={'width': 0.4, 'edgecolor': 'white'}  # makes it donut
)

plt.title("Revenue Distribution by Food Category", fontsize=14, weight='bold')

plt.tight_layout()
plt.show()

# %%
# Donut chart
fig = px.pie(
    food_revenue,
    names="food_category",
    values="Price (INR)",
    hole=0.5,  # donut effect
   # color_discrete_sequence=px.colors.sequential.Reds  # strong dark colors
)

# Layout customization
fig.update_traces(
    textinfo='percent+label',
    textfont_size=12,
    pull = [0.05,0]
)

fig.update_layout(
    title="Revenue Distribution by Food Category",
    title_x=0.5,
    #template="plotly_dark",  # dark background
    font=dict(size=13),
    margin = dict(t=60, b=40, l=40,r=40)
)

fig.show()
# Out:
# <div>                            <div id="7561b52e-5baa-4718-aeeb-60913622fffc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7561b52e-5baa-4718-aeeb-60913622fffc")) {                    Plotly.newPlot(                        "7561b52e-5baa-4718-aeeb-60913622fffc",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.5,"hovertemplate":"food_category=%{label}<br>Price (INR)=%{value}<extra></extra>","labels":["Non-Veg","Veg"],"legendgroup":"","name":"","showlegend":true,"values":[18659307.78,34353197.99],"type":"pie","textfont":{"size":12},"pull":[0.05,0],"textinfo":"percent+label"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6"
# ...

# %% [markdown]
# ### Total Sales by State

# %%
fig = px.bar(
    df.groupby("State",as_index = False)["Price (INR)"].sum()
    .sort_values("Price (INR)", ascending = False),
    x = "Price (INR)",
    y = "State",
    orientation = "h",
    title = "Revenue by State (INR)"
)
fig.update_layout(height = 600, yaxis=dict(autorange="reversed"))
fig.show()
# Out:
# <div>                            <div id="37f9e896-047e-49bc-8a0a-6c7ef9a3f0c6" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("37f9e896-047e-49bc-8a0a-6c7ef9a3f0c6")) {                    Plotly.newPlot(                        "37f9e896-047e-49bc-8a0a-6c7ef9a3f0c6",                        [{"alignmentgroup":"True","hovertemplate":"Price (INR)=%{x}<br>State=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[5456798.41,3117359.65,3021711.62,3015573.35,2829180.6,2817836.02,2809440.69,2662801.76,2642594.63,2502932.61,1970100.77,1539479.41,1438455.54,1427851.75,1382689.18,1322513.82,1301699.7,1283926.46,1259012.24,1254429.93,
# ...

# %% [markdown]
# ### Quarterly Performance Summary

# %%
df["order_date"] = pd.to_datetime(df["Order Date"])

df["Quarter"] = df["order_date"].dt.to_period("Q").astype(str)

# %%
quarterly_summary = df.groupby("Quarter").agg(
    Total_Sales=("Price (INR)", "sum"),
    Total_Orders=("Price (INR)", "count"),
    Avg_Rating=("Rating", "mean")
).reset_index()

# %%
quarterly_summary
# Out:
#   Quarter  Total_Sales  Total_Orders  Avg_Rating
# 0  2025Q1  19667821.77         73096    4.342643
# 1  2025Q2  19902256.59         74163    4.340011
# 2  2025Q3  13442427.41         50171    4.342359

# %%
import plotly.graph_objects as go

fig = go.Figure()

# Sales (Bar)
fig.add_trace(go.Bar(
    x=quarterly_summary["Quarter"],
    y=quarterly_summary["Total_Sales"],
    name="Total Sales",
))

# Orders (Line)
fig.add_trace(go.Scatter(
    x=quarterly_summary["Quarter"],
    y=quarterly_summary["Total_Orders"],
    mode="lines+markers",
    name="Total Orders",
    yaxis="y2"
))

# Ratings (Line)
fig.add_trace(go.Scatter(
    x=quarterly_summary["Quarter"],
    y=quarterly_summary["Avg_Rating"],
    mode="lines+markers",
    name="Avg Rating",
    yaxis="y3"
))

# Layout (Dark + Multiple Axes)
fig.update_layout(
    template="plotly_dark",
    title="Quarterly Performance Summary",
    title_x=0.5,

    yaxis=dict(title="Sales (INR)"),
    
    yaxis2=dict(
        title="Orders",
        overlaying="y",
        side="right"
    ),
    
    yaxis3=dict(
        #title="Rating",
        anchor="free",
        overlaying="y",
        side="right",
        position=0.95
    )
    
)

fig.show()
# Out:
# <div>                            <div id="077dcdb2-74ed-4852-889f-cda457527f71" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("077dcdb2-74ed-4852-889f-cda457527f71")) {                    Plotly.newPlot(                        "077dcdb2-74ed-4852-889f-cda457527f71",                        [{"name":"Total Sales","x":["2025Q1","2025Q2","2025Q3"],"y":[19667821.77,19902256.59,13442427.41],"type":"bar"},{"mode":"lines+markers","name":"Total Orders","x":["2025Q1","2025Q2","2025Q3"],"y":[73096,74163,50171],"yaxis":"y2","type":"scatter"},{"mode":"lines+markers","name":"Avg Rating","x":["2025Q1","2025Q2","2025Q3"],"y":[4.342642552260042,4.3400105173738925,4.342359131769348],"yaxis":"y3","type":"scatter"}],                        {"template":{"data":{"barpol
# ...

# %% [markdown]
# ### TOP 5 Cities By Sales

# %%
city_sales = (
    df.groupby("City")["Price (INR)"]
    .sum()
    .reset_index()
)

# %%
top5_cities = city_sales.sort_values(by="Price (INR)", ascending=False).head(5)

fig = px.bar(
    top5_cities,
    x="Price (INR)",
    y="City",
    orientation="h",
    title="Top 5 Cities by Sales",
    color="City",
)

fig.update_layout(
    template="plotly_dark",
    title_x=0.5
)

fig.show()
# Out:
# <div>                            <div id="678b34b4-85f6-4078-a2ed-5097ecc97163" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("678b34b4-85f6-4078-a2ed-5097ecc97163")) {                    Plotly.newPlot(                        "678b34b4-85f6-4078-a2ed-5097ecc97163",                        [{"alignmentgroup":"True","hovertemplate":"City=%{y}<br>Price (INR)=%{x}<extra></extra>","legendgroup":"Bengaluru","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Bengaluru","offsetgroup":"Bengaluru","orientation":"h","showlegend":true,"textposition":"auto","x":[5456798.41],"xaxis":"x","y":["Bengaluru"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"City=%{y}<br>Price (INR)=%{x}<extra></extra>","legendgroup":"Lucknow","marker":{"co
# ...

# %% [markdown]
# ### Weekly Trend Analysis

# %%
df["order_date"] = pd.to_datetime(df["Order Date"])

# Extract week
df["Week"] = df["order_date"].dt.to_period("W").astype(str)

# %%
weekly_sales = (
    df.groupby("Week")["Price (INR)"]
    .sum()
    .reset_index()
)

# %%
fig = px.line(
    weekly_sales,
    x="Week",
    y="Price (INR)",
    title="Weekly Sales Trend (Fluctuation Analysis)",
    markers=True
)

fig.update_layout(
    template="plotly_dark",
    title_x=0.5,
    xaxis_title="Week",
    yaxis_title="Sales (INR)"
)

fig.show()
# Out:
# <div>                            <div id="66adb529-e2a5-4f5f-9548-67e79dc5e3b7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("66adb529-e2a5-4f5f-9548-67e79dc5e3b7")) {                    Plotly.newPlot(                        "66adb529-e2a5-4f5f-9548-67e79dc5e3b7",                        [{"hovertemplate":"Week=%{x}<br>Price (INR)=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"","orientation":"v","showlegend":false,"x":["2024-12-30/2025-01-05","2025-01-06/2025-01-12","2025-01-13/2025-01-19","2025-01-20/2025-01-26","2025-01-27/2025-02-02","2025-02-03/2025-02-09","2025-02-10/2025-02-16","2025-02-17/2025-02-23","2025-02-24/2025-03-02","2025-03-03/2025-03-09",
# ...

# %%
weekly_sales["Moving_Avg"] = weekly_sales["Price (INR)"].rolling(3).mean()

import plotly.graph_objects as go

fig = go.Figure()

# Actual sales
fig.add_trace(go.Scatter(
    x=weekly_sales["Week"],
    y=weekly_sales["Price (INR)"],
    mode="lines+markers",
    name="Weekly Sales"
))

# Moving average
fig.add_trace(go.Scatter(
    x=weekly_sales["Week"],
    y=weekly_sales["Moving_Avg"],
    mode="lines",
    name="3-Week Avg"
))

fig.update_layout(
    template="plotly_dark",
    title="Weekly Sales with Trend Line",
    title_x=0.5
)
peak_value = weekly_sales["Price (INR)"].max()

fig.add_annotation(
    x=weekly_sales.loc[weekly_sales["Price (INR)"].idxmax(), "Week"],
    y=peak_value,
    text="Peak Sales 🚀",
    showarrow=True
)

fig.show()
# Out:
# <div>                            <div id="73b57147-fb2f-45d3-8290-6bcf22928b1f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("73b57147-fb2f-45d3-8290-6bcf22928b1f")) {                    Plotly.newPlot(                        "73b57147-fb2f-45d3-8290-6bcf22928b1f",                        [{"mode":"lines+markers","name":"Weekly Sales","x":["2024-12-30/2025-01-05","2025-01-06/2025-01-12","2025-01-13/2025-01-19","2025-01-20/2025-01-26","2025-01-27/2025-02-02","2025-02-03/2025-02-09","2025-02-10/2025-02-16","2025-02-17/2025-02-23","2025-02-24/2025-03-02","2025-03-03/2025-03-09","2025-03-10/2025-03-16","2025-03-17/2025-03-23","2025-03-24/2025-03-30","2025-03-31/2025-04-06","2025-04-07/2025-04-13","2025-04-14/2025-04-20","2025-04-21/2025-04-27","2025-04
# ...
